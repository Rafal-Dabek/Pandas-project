# %%
import pandas as pd
import matplotlib.pyplot as plt
pilkarze = pd.read_csv('players_21.csv', sep=',')

del pilkarze['sofifa_id']
del pilkarze['player_url']
del pilkarze['long_name']
del pilkarze['dob']
del pilkarze['rb']
del pilkarze['rcb']
del pilkarze['cb']
del pilkarze['lcb']
del pilkarze['lb']
del pilkarze['rwb']
del pilkarze['rdm']
del pilkarze['cdm']
del pilkarze['ldm']
del pilkarze['lwb']
del pilkarze['rm']
del pilkarze['rcm']
del pilkarze['cm']
del pilkarze['lcm']
del pilkarze['lm']
del pilkarze['ram']
del pilkarze['cam']
del pilkarze['lam']
del pilkarze['rw']
del pilkarze['rf']
del pilkarze['cf']
del pilkarze['lf']
del pilkarze['lw']
del pilkarze['rs']
del pilkarze['ls']
del pilkarze['st']
del pilkarze['defending_marking']
pilkarze['value/overall']=pilkarze['value_eur']/pilkarze['overall']
#pilkarze.describe()
#pilkarze.sort_values('wage_eur',ascending='False')
del pilkarze['league_rank']
del pilkarze['real_face']
del pilkarze['loaned_from']

manu=pilkarze.loc[pilkarze['club_name']=="Manchester United"].sort_values('wage_eur',ascending=False)
dane14=manu["overall"][0:10]
#plt.plot(range(len(dane14)),dane14,"ro",label="2014")
psg=pilkarze.loc[pilkarze['club_name']=="Paris Saint-Germain"].sort_values('wage_eur',ascending=False)
dane15=psg["overall"][0:10]
#plt.plot(range(len(dane15)),dane15,"ro",label="2014")
bins=[60,65,70,75,80,85,90]
plt.hist(manu.overall,bins=bins)
plt.xticks(bins)
plt.show()
#pilkarze.sort_values('value/overall',ascending=False)
bpl_players=pilkarze.loc[pilkarze['league_name']=="English Premier League"].sort_values('wage_eur',ascending=False)
dane_bpl=bpl_players["value_eur"][0:10]
dane_bpl
bpl_players
# Out:
#               short_name  age  height_cm  weight_kg  nationality  \
# 5           K. De Bruyne   29        181         70      Belgium
# 13             S. Agüero   32        173         70    Argentina
# 19           R. Sterling   25        170         69      England
# 10               S. Mané   28        175         69      Senegal
# 11              M. Salah   28        175         71        Egypt
# ...                  ...  ...        ...        ...          ...
# 14725         E. Caprile   18        191         74        Italy
# 18345          K. Gordon   18        187         76      England
# 16079  Christian Marques   17        187         75  Switzerland
# 17576       C. Cresswell   17        191         80      England
# 13890        L. Matheson   17        168         62      England
#
#                      club_name             league_name  overall  potential  \
# 5              Manchester City  English Premier League       91         91
# 13             Manchester City  English Premier League       89         89
# 19             Manchester City  English Premier League       88         90
# 10                   Liverpool  English Premier League       90         90
# 11                   Liverpool  English Premier League       90         90
# ...                        ...                     ...      ...        ...
# 14725             Leeds United  English Premier League       60         78
# 18345         Sheffield United  English Premier League       52         70
# 16079  Wolverhampton Wanderers  English Premier League       58         80
# 17576             Leeds United  English Premier League       55         70
# 13890  Wolverhampton Wanderers  English Premier League       61         82
#
#        value_eur  ...  mentality_penalties mentality_composure  \
# 5       87000000  ...                   84                  91
# 13      53000000  ...                   75                  91
# 19      72500000  ...                   69                  80
# 10      78000000  ...                   71                  84
# 11      78000000  ...                   83                  90
# ...          ...  ...                  ...                 ...
# 14725     350000  ...                   18                  33
# 18345     100000  ...                   30                  36
# 16079     250000  ...                   46                  63
# 17576     150000  ...                   39                  46
# 13890     500000  ...                   34                  51
#
#       defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 5                            65                        53                  15
# 13                           29                        24                  13
# 19                           53                        47                  15
# 10                           42                        38                  10
# 11                           43                        41                  14
# ...                         ...                       ...                 ...
# 14725                        11                        14                  63
# 18345                        53                        54                  10
# 16079                        60                        59                  15
# 17576                        59                        56                  11
# 13890                        54                        55                  11
#
#        goalkeeping_handling goalkeeping_kicking goalkeeping_positioning  \
# 5                        13                   5                      10
# 13                       15                   6                      11
# 19                       12                  12                      15
# 10                       10                  15                       7
# 11                       14                   9                      11
# ...                     ...                 ...                     ...
# 14725                    59                  61                      58
# 18345                     5                   9                       6
# 16079                    15                   7                      11
# 17576                    11                  13                      10
# 13890                     9                   6                      11
#
#        goalkeeping_reflexes  value/overall
# 5                        13  956043.956044
# 13                       14  595505.617978
# 19                        9  823863.636364
# 10                       14  866666.666667
# 11                       14  866666.666667
# ...                     ...            ...
# 14725                    63    5833.333333
# 18345                    11    1923.076923
# 16079                     7    4310.344828
# 17576                    11    2727.272727
# 13890                     8    8196.721311
#
# [654 rows x 73 columns]
